# %% [markdown]
# <h1><center>Youtube API Analysis</center></h1>
#
# <img src="Youtube api analysis image.png" width="400" height="400" align="Center"/>

# %%
#importing the libraries
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
#api key usage 
api_key = 'AIzaSyAbmEbgH5D75Pswt_uBiHyPOYlaeP8zxX8'

#channel_id = 'UCnz-ZXXER4jOvuED5trXfEA'

channel_ids = ['UCnz-ZXXER4jOvuED5trXfEA', #techTFQ
               'UCLLw7jmFsvfIVaUFsLs8mlQ', #Luke Barousse
               'UCiT9RITQ9PW6BhXK0y2jaeg', #Ken Jee
               'UC7cs8q-gJRlGwj4A8OmCmXg', #Alex the Analyst
               'UC2UXDak6o7rBm23k3Vv5dww'] # Tina Huang 
youtube = build('youtube','v3',developerKey = api_key)

# %% [markdown]
# ### Function to get channel statistics

# %%
def get_channel_stats(youtube,channel_ids):
    all_data = []
    
    request = youtube.channels().list(
              part = 'snippet,contentDetails,statistics',
              id = ','.join(channel_ids))
    response = request.execute()
    for i in range(len(response['items'])):
        data = dict(Channel_name  = response['items'][i]['snippet']['title'],
                Subscribers = response['items'][i]['statistics']['subscriberCount'],
                Views = response['items'][i]['statistics']['viewCount'],
                Videos = response['items'][i]['statistics']['videoCount'],
                playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    return all_data

# %%
channel_stats = get_channel_stats(youtube,channel_ids)

# %%
channel_data = pd.DataFrame(channel_stats)

# %%
channel_data
# Out:
#        Channel_name Subscribers     Views Videos               playlist_id
# 0        Tina Huang      378000  14799485    106  UU2UXDak6o7rBm23k3Vv5dww
# 1     Luke Barousse      215000  10083135     77  UULLw7jmFsvfIVaUFsLs8mlQ
# 2           Ken Jee      212000   6733777    237  UUiT9RITQ9PW6BhXK0y2jaeg
# 3           techTFQ       97700   4551591     65  UUnz-ZXXER4jOvuED5trXfEA
# 4  Alex The Analyst      260000  10358759    157  UU7cs8q-gJRlGwj4A8OmCmXg

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Videos          object
# playlist_id     object
# dtype: object

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Videos'] = pd.to_numeric(channel_data['Videos'])

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Videos           int64
# playlist_id     object
# dtype: object

# %%
channel_data.to_csv('Channel_details of 5 DataScience YT Tutors')

# %%
sns.set(rc = {'figure.figsize' : (10,8)})
ax = sns.barplot(x = 'Channel_name',y = 'Subscribers', data = channel_data )

# %%
ax = sns.barplot(x = 'Channel_name',y = 'Views', data = channel_data )

# %%
ax = sns.barplot(x = 'Channel_name',y = 'Videos', data = channel_data )

# %% [markdown]
# ### Function to get video ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name'] =='Alex The Analyst','playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UU7cs8q-gJRlGwj4A8OmCmXg'

# %%
def get_video_ids(youtube,playlist_id):
    request = youtube.playlistItems().list(
              part = 'contentDetails',
              playlistId = playlist_id,
              maxResults = 50 )
               
    response = request.execute()
    video_ids = []
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            
            request = youtube.playlistItems().list(
                        part = 'contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
            
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
                next_page_token = response.get('nextPageToken')
            
    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['ulFY20KTzFQ',
#  'PEc29sRZoTM',
#  'DlEkWd-8VXA',
#  'vcijg0gUXSg',
#  'gCg47n_TlFc',
#  'sW5LoDA1ssM',
#  '4nsdARJGzJ0',
#  '_QvQxm4dptI',
#  'HX2TabgkzHo',
#  'gP-AxNi6uxo',
#  'KB2CtEDrglY',
#  '2HfSFdPEFRg',
#  'g0m5sEHPU-s',
#  'Q7i6zxHVj2Q',
#  'ddn-2r1j_OU',
#  'Pf-9pjJK1e0',
#  '-bSkREem8dM',
#  'xKdtP3IZbnU',
#  'GsAXOr715AU',
#  '2JnlQ8jwWbE',
#  'hNTNZ00cZig',
#  'gz2j5NBESSs',
#  'opJgMj1IUrc',
#  'yRWkSKRYCaI',
#  '_jmiEGZ6PIY',
#  '4A8LV6fObYA',
#  'MPENhkuSo0Q',
#  '3irO29PJQHs',
#  'uHJFJUIYNAo',
#  'gMAHXrty6wI',
#  'BIUFr9srS78',
#  '_eZRkmRfVTM',
#  's3JmRxs53W4',
#  'yDG5KiiOZcQ',
#  'Z7hPEwCzk2s',
#  'XRPyj7cKVsQ',
#  'lH7HfwUFnYA',
#  'zOR0-nygfDE',
#  'A4SVUF-fTwc',
#  'FnTunxd8tAM',
#  '-_z_aphWSEo',
#  'pL0jEjeM5hI',
#  'eg_5EAUXs5o',
#  'ebjDwX8sUMk',
#  'f6qxxtWkaUg',
#  '6xv1KvCMF1Q',
#  '465x3JmMJYU',
#  'Ns1ZpTxQnUE',
#  'HiOtQMcI5wg',
#  'CUa30M_FPhk',
#  'DKrSgSy6F1o',
#  '_zxPx1PQCqI',
#  'UGF49YZZRNc',
#  'aLp-6C-p-T0',
#  'ocdwh0KYeUs',
#  'iPYVYBtUTyE',
#  'dMHWOhgzUhU',
#  'A-LkxegXFX8',
#  'RJw-GSXXguA',
#  '8rO7ztF4NtU',
#  'QILNlRvJlfQ',
#  'SVv0WwPzaUg',
#  'qfyynHBFOsM',
#  'm1KcNV-Zhmc',
#  'IZRe0nwkuXc',
#  '9RRQtNnq3s0',
#  'qewHAdfzLOw',
#  'bHssBHfHWmU',
#  'A4OVjWeVb10',
#  'SIseim20_Dc',
#  'NrBJmtD0kEw',
#  'wnapnTAMj68',
#  'duMcYRtQITA',
#  'QG1fo7LFesA',
#  'pYRG5X7110M',
#  'NViKsiGP4TY',
#  '1gdKC5O0Pwc',
#  'GQj6_6V_jVA',
#  'RF0LE3hYFrI',
#  '8o-O6pR6yAE',
#  'eFDbE5Yunj0',
#  'D9bNctNnAig',
#  'VsztBAEtC7c',
#  'T3KMZoXrVTQ',
#  'tJaDicmRW7s',
#  'hfRcaRw_atI',
#  'aPDOGxrONy0',
#  'w25ZjL0OqT4',
#  'EWPeAXrF3zg',
#  'ru0Xdvxd37Q',
#  'BAVPAYWAoC4',
#  'whgwEwA5SHU',
#  'K1WeoKxLZ5o',
#  '0HRgbb1PcDQ',
#  'D6XNlTfglW4',
#  'MQ5UUNjWgug',
#  'JikLVP9DkPs',
#  'yzqpYs7dIqY',
#  '7uH7_DThtX0',
#  'GGLF2jLo8J4',
#  'BGBXnNvWdQ4',
#  'PurMLMKNX0I',
#  'pvxNYyJuiqA',
#  'rZpfNh28nFI',
#  'brxnKIy6Cek',
#  'ySq0cgkZiX4',
#  'aJ9Q10v8Nrc',
#  'C2ik_qR5GOU',
#  'mLUzFXPPa4I',
#  'XmFhpoS6Etk',
#  '1xT68oeQTd0',
#  'eTsHJoMmhYQ',
#  '8SolrjsGqzE',
#  'SKsjWzzz4mY',
#  'Z2AachB309o',
#  '_gP-DH0iZLw',
#  '-Inc1be4zSg',
#  'CsMh7Ykmnw4',
#  'ho2vzKPAD50',
#  '5MZo2RoS8Yo',
#  'M2ySRYpo9S0',
#  'ncXgqGePvwI',
#  'ywZXpfdqg1o',
#  'IqQCBytyATo',
#  'MpIi4HtCiVk',
#  'G4syHs3M82E',
#  'appOFpF2pFg',
#  'B2SPC3Wz1R8',
#  'fUpChfNN5Uo',
#  'Dk7he_yEs4U',
#  'LJtFgnHGAos',
#  'ziurEoqEcO4',
#  'rLKC--8UYSw',
#  'sua7xKN0cPc',
#  'fweZQqB0nwQ',
#  'oXAwKZWfbW0',
#  'bhnrIforc7s',
#  'tYBOMw7Ob8E',
#  'Twusw__OzA8',
#  'lYKkro6rKm0',
#  '9URM1_2S0ho',
#  'qzZU6LAtIig',
#  'LXwfzIRD-Ds',
#  'A9TOuDZTPDU',
#  'PyYgERKq25I',
#  'RSlqWnP-Dy8',
#  '9o9loJpG-t4',
#  'Lacbh0VoT3g',
#  'oZKs2xMbXQE',
#  'N8f7NtDpbxA',
#  'wcKzdRVsMOw',
#  'Ns-8Jsa3mEM',
#  '4rfr6A3lO-Y',
#  'OTq2NRy_AGs',
#  'ya28cb3zFGE',
#  'Hsi2BG0SOiQ',
#  '6lQzbk6_OTw']

# %%
len(video_ids)
# Out:
# 157

# %% [markdown]
# ### Function to get video details

# %%
def get_video_details(youtube,video_ids):
    
    all_video_stats = []
    
    for i in range(0, len(video_ids) , 50):
        request = youtube.videos().list(
              part = 'snippet,statistics',
              id = ','.join(video_ids[i:i+50]))
        response = request.execute()
    
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                           Published_date = video['snippet']['publishedAt'],
                           Views = video['statistics']['viewCount'],
                           Likes = video['statistics']['likeCount'],
                           Comments = video['statistics']['commentCount'])
        
            all_video_stats.append(video_stats)
        
    return all_video_stats

# %%
video_details = get_video_details(youtube,video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                  Title        Published_date  \
# 0    How to use Drill Down in Power BI | Microsoft ...  2022-08-09T10:30:11Z
# 1    Best Courses for Alternative Analyst Jobs | Ma...  2022-08-02T10:30:05Z
# 2                        250k Subscriber Live Stream!!  2022-07-26T13:19:48Z
# 3    How to use DAX in Power BI | Microsoft Power B...  2022-07-26T10:30:12Z
# 4    Tech Layoffs and Hiring Freezes | The Great Re...  2022-07-19T10:30:06Z
# ..                                                 ...                   ...
# 152  Data Analyst Resume | Reviewing My Resume! | F...  2020-01-30T14:07:55Z
# 153  Working at a Big Company Vs Small Company | To...  2020-01-25T16:38:39Z
# 154      Data Analyst Salary | 100k with No Experience  2020-01-23T03:16:09Z
# 155  Truth About Big Companies | Told by a Fortune ...  2020-01-21T03:52:15Z
# 156                  Top 3 Data Analyst Skills in 2020  2020-01-17T14:31:39Z
#
#      Views Likes Comments
# 0     1550    89       11
# 1     9628   522       55
# 2     3787   157       10
# 3     4143   192       21
# 4    14994   475      110
# ..     ...   ...      ...
# 152  50163  1296       63
# 153  10277   305       18
# 154  49017  1769      205
# 155   6038   231       17
# 156  23597  1197      138
#
# [157 rows x 5 columns]

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])

# %%
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0    How to use Drill Down in Power BI | Microsoft ...     2022-08-09   1550
# 1    Best Courses for Alternative Analyst Jobs | Ma...     2022-08-02   9628
# 2                        250k Subscriber Live Stream!!     2022-07-26   3787
# 3    How to use DAX in Power BI | Microsoft Power B...     2022-07-26   4143
# 4    Tech Layoffs and Hiring Freezes | The Great Re...     2022-07-19  14994
# ..                                                 ...            ...    ...
# 152  Data Analyst Resume | Reviewing My Resume! | F...     2020-01-30  50163
# 153  Working at a Big Company Vs Small Company | To...     2020-01-25  10277
# 154      Data Analyst Salary | 100k with No Experience     2020-01-23  49017
# 155  Truth About Big Companies | Told by a Fortune ...     2020-01-21   6038
# 156                  Top 3 Data Analyst Skills in 2020     2020-01-17  23597
#
#      Likes  Comments
# 0       89        11
# 1      522        55
# 2      157        10
# 3      192        21
# 4      475       110
# ..     ...       ...
# 152   1296        63
# 153    305        18
# 154   1769       205
# 155    231        17
# 156   1197       138
#
# [157 rows x 5 columns]

# %%
#Top 10 videos ie bases on views
top_10_videos = video_data.sort_values(by = 'Views',ascending=False).head(10)

# %%
top_10_videos
# Out:
#                                                  Title Published_date   Views  \
# 120         Top 5 Reasons Not to Become a Data Analyst     2020-08-12  717151
# 62   Data Analyst Portfolio Project | SQL Data Expl...     2021-05-04  634522
# 125  Data Analyst vs Business Analyst | Which Is Ri...     2020-07-03  607810
# 128  Data Scientist vs Data Analyst | Which Is Righ...     2020-06-10  602349
# 122              What Does a Data Analyst Actually Do?     2020-07-29  483123
# 33                How To Become A Data Analyst In 2022     2022-01-04  331664
# 145  SQL Basics Tutorial For Beginners | Installing...     2020-03-01  326190
# 114  How I Changed Careers to Become a Data Analyst...     2020-09-10  324088
# 56   How To Get a Data Analyst Job (with No Experie...     2021-06-08  296250
# 71   Google Data Analytics Professional Certificate...     2021-03-12  289680
#
#      Likes  Comments
# 120  15903       964
# 62   14564      1623
# 125  15740       576
# 128  19224       759
# 122  10823       364
# 33   15787       520
# 145   5643       434
# 114   9922      3169
# 56   13788       524
# 71    9560      1125

# %%
ax1 = sns.barplot(x = 'Views',y = 'Title',data = top_10_videos)

# %%
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0    How to use Drill Down in Power BI | Microsoft ...     2022-08-09   1550
# 1    Best Courses for Alternative Analyst Jobs | Ma...     2022-08-02   9628
# 2                        250k Subscriber Live Stream!!     2022-07-26   3787
# 3    How to use DAX in Power BI | Microsoft Power B...     2022-07-26   4143
# 4    Tech Layoffs and Hiring Freezes | The Great Re...     2022-07-19  14994
# ..                                                 ...            ...    ...
# 152  Data Analyst Resume | Reviewing My Resume! | F...     2020-01-30  50163
# 153  Working at a Big Company Vs Small Company | To...     2020-01-25  10277
# 154      Data Analyst Salary | 100k with No Experience     2020-01-23  49017
# 155  Truth About Big Companies | Told by a Fortune ...     2020-01-21   6038
# 156                  Top 3 Data Analyst Skills in 2020     2020-01-17  23597
#
#      Likes  Comments
# 0       89        11
# 1      522        55
# 2      157        10
# 3      192        21
# 4      475       110
# ..     ...       ...
# 152   1296        63
# 153    305        18
# 154   1769       205
# 155    231        17
# 156   1197       138
#
# [157 rows x 5 columns]

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0    How to use Drill Down in Power BI | Microsoft ...     2022-08-09   1550
# 1    Best Courses for Alternative Analyst Jobs | Ma...     2022-08-02   9628
# 2                        250k Subscriber Live Stream!!     2022-07-26   3787
# 3    How to use DAX in Power BI | Microsoft Power B...     2022-07-26   4143
# 4    Tech Layoffs and Hiring Freezes | The Great Re...     2022-07-19  14994
# ..                                                 ...            ...    ...
# 152  Data Analyst Resume | Reviewing My Resume! | F...     2020-01-30  50163
# 153  Working at a Big Company Vs Small Company | To...     2020-01-25  10277
# 154      Data Analyst Salary | 100k with No Experience     2020-01-23  49017
# 155  Truth About Big Companies | Told by a Fortune ...     2020-01-21   6038
# 156                  Top 3 Data Analyst Skills in 2020     2020-01-17  23597
#
#      Likes  Comments Month
# 0       89        11   Aug
# 1      522        55   Aug
# 2      157        10   Jul
# 3      192        21   Jul
# 4      475       110   Jul
# ..     ...       ...   ...
# 152   1296        63   Jan
# 153    305        18   Jan
# 154   1769       205   Jan
# 155    231        17   Jan
# 156   1197       138   Jan
#
# [157 rows x 6 columns]

# %%
videos_per_month = video_data.groupby('Month',as_index= False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    13
# 1    Aug    11
# 2    Dec    13
# 3    Feb    15
# 4    Jan    17
# 5    Jul    11
# 6    Jun    13
# 7    Mar    18
# 8    May    14
# 9    Nov    11
# 10   Oct    12
# 11   Sep     9

# %%
sort_order = ['Jan','Feb','Mar','Apr','May','Jun',
              'Jul','Aug','Sep','Oct','Nov','Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'],categories=sort_order,ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
videos_per_month
# Out:
#       Month  size
# Month
# Jan     Jan    17
# Feb     Feb    15
# Mar     Mar    18
# Apr     Apr    13
# May     May    14
# Jun     Jun    13
# Jul     Jul    11
# Aug     Aug    11
# Sep     Sep     9
# Oct     Oct    12
# Nov     Nov    11
# Dec     Dec    13

# %%
ax2 = sns.barplot(x = 'Month',y= 'size',data = videos_per_month)

# %%
video_data.to_csv('Video_Details(Alex The Analyst)')
